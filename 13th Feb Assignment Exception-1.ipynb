# %%
# 13th Feb Assignment Question Exception -1

"""Q1.Explain why we have to use the Exception class while creating a Custom Exception."""
Ans: The Exception class is the base class for all built-in exceptions in Python. When creating a 
custom exception, it is important to inherit from the Exception class so that the custom exception 
can be caught and handled properly. This allows us to create a hierarchy of exceptions that can be 
used to catch and handle different types of errors.

Inheriting from the Exception class also allows us to use the built-in exception handling mechanisms 
in Python, such as try/except blocks and the raise statement. This makes it easier to create robust 
error handling code that can be used to handle different types of errors.

Finally, inheriting from the Exception class allows us to create custom exceptions that are compatible 
with the existing exception handling mechanisms in Python. This makes it easier to integrate our custom 
exceptions into existing code without having to rewrite large portions of code.

"""Q2.Write a python program to print Python Exception Hierarchy."""
Ans: # import inspect module
import inspect
  
# our pwskills function
def pwskills(cls, j = 0):
    
      # print name of the class
    print ('-' * j, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        pwskills(i, j + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(BaseException)

"""Q3. What errors are defined in the ArithmeticError class? Explain any two with an example."""
Ans: The ArithmeticError class is a built-in Python exception class that is raised when an error occurs 
in an arithmetic operation. The errors defined in the ArithmeticError class are: 

1. OverflowError: This error is raised when the result of an arithmetic operation exceeds the maximum 
limit for a numeric type. For example, if you try to add two numbers that are too large to fit in an 
integer, an OverflowError will be raised.

2. ZeroDivisionError: This error is raised when a number is divided by zero. For example, if you try to 
divide a number by zero, a ZeroDivisionError will be raised.

"""Q4. Why LookupError class is used? Explain with an example KeyError and IndexError."""
Ans: LookupError is a class used to represent errors that occur when attempting to access an item in a 
data structure that does not exist. It is the parent class of two other classes, KeyError & IndexError. 

KeyError is raised when a key is not found in a dictionary. For example, if you try to access a key 
that does not exist in a dictionary, you will get a KeyError:

my_dict = {'a': 1, 'b': 2}

# Trying to access a key that does not exist
print(my_dict['c'])

# Output: KeyError: 'c'

IndexError is raised when an index is not found in a sequence. For example, if you try to access an 
index that does not exist in a list, you will get an IndexError:

my_list = [1, 2, 3]

# Trying to access an index that does not exist
print(my_list[3])

# Output: IndexError: list index out of range

"""Q5. Explain ImportError. What is ModuleNotFoundError?"""
Ans: ImportError is an exception raised when a module or package cannot be found. It is usually raised 
when the import statement fails to locate the module, or when an imported module attempts to import a 
module that cannot be found.

ModuleNotFoundError is a subclass of ImportError that is raised when a module cannot be found. It's 
usually raised when the import statement fails to locate the module, or when an imported module 
attempts to import a module that cannot be found.

"""Q6. List down some best practices for exception handling in python."""
Ans: 
1. "Use try-except blocks:" Try-except blocks are the most common way to handle exceptions in Python.
They allow you to catch and handle errors gracefully, without crashing your program.

2. "Use the finally block:" The finally block is used to execute code regardless of whether an exception 
is raised or not. This is useful for cleaning up resources, such as closing files or database connections.

3. "Use logging:" Logging is a great way to keep track of errors and other events in your program. It can 
help you debug issues and identify potential problems before they become major issues.

4. "Don’t ignore exceptions:" Ignoring exceptions is a bad practice and can lead to unexpected behavior 
in your program. Always make sure to handle exceptions properly.

5. "Use custom exceptions:" Custom exceptions are a great way to add more context to errors  and make 
them easier to debug. They also allow you to create more specific error messages that are tailored to your application.
